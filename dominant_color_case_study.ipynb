# %%
# for image recogonition 
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
image = cv2.imread('image1.jpg')
print image
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...,
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print image
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...,
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
image.shape
# Out:
# (618928L, 3L)

# %%
plt.figure()
plt.axis("off")
plt.imshow(image)

# %%
image = image.reshape((image.shape[0]*image.shape[1],3))
print image
print image.shape
# Out:
# [[255 255 255]
#  [255 255 255]
#  [255 255 255]
#  ...,
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]]
# (618928L, 3L)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(image)

# %%
# initialising the label dictionary
label = [0,0,0]

# %%
# finding count of data in each cluster
for x in kmeans.labels_:
    label[x] += 1

# %%
# total number of data points
label_sum = image.shape[0]

# %%
#converting to percentage
label = [float(x)/label_sum for x in label]
print label
# Out:
# [0.3133773233720239, 0.5926585967996277, 0.09396407982834837]

# %%
print kmeans.cluster_centers_
# Out:
# [[ 254.18389643  254.18076171  254.17903453]
#  [  22.41275848   21.89548683   21.04670747]
#  [ 177.8245065   155.11756311   89.74475549]]

# %%
centroids = [x.astype('uint8').tolist() for x in kmeans.cluster_centers_]

# %%
import webcolors

# %%
clr = [webcolors.rgb_to_hex(c) for c in centroids]

# %%
# ploting pie chart
plt.pie(label, colors=clr, shadow=True)
plt.axis('equal')
plt.show()

# %%
image1 = cv2.imread('image2.png')
image1.shape
# Out:
# (828L, 921L, 3L)

# %%
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
print image1
print image1.shape
# Out:
# [[[242 242 242]
#   [242 242 242]
#   [242 242 242]
#   ...,
#   [242 242 242]
#   [242 242 242]
#   [242 242 242]]
#
#  [[242 242 242]
#   [242 242 242]
#   [242 242 242]
#   ...,
#   [242 242 242]
#   [242 242 242]
#   [242 242 242]]
#
#  [[242 242 242]
#   [242 242 242]
#   [242 242 242]
#   ...,
#   [242 242 242]
#   [242 242 242]
#   [242 242 242]]
#
#  ...,
#  [[241 241 241]
#   [241 241 241]
#   [241 241 241]
#   ...,
#   [241 241 241]
#   [241 241 241]
#   [241 241 241]]
#
#  [[241 241 241]
#   [241 241 241]
#   [241 241 241]
#   ...,
#   [241 241 241]
#   [241 241 241]
#   [241 241 241]]
#
#  [[241 241 241]
#   [241 241 241]
#   [241 241 241]
#   ...,
#   [241 241 241]
#   [241 241 241]
#   [241 241 241]]]
# (828L, 921L, 3L)

# %%
image1 = image1.reshape((image1.shape[0]*image1.shape[1],3))

# %%
kmeans = KMeans(n_clusters=5,random_state=0).fit(image1)

# %%
label = [0,0,0,0,0]
for x in kmeans.labels_:
    label[x] += 1
# total number of data points
label_sum = image1.shape[0]
#converting to percentage
label = [float(x)/label_sum for x in label]
print label
print kmeans.cluster_centers_
centroids = [x.astype('uint8').tolist() for x in kmeans.cluster_centers_]
clr = [webcolors.rgb_to_hex(c) for c in centroids]
plt.pie(label, colors=clr, shadow=True)
plt.axis('equal')
plt.show()
# Out:
# [0.26496483028843887, 0.6770575985984568, 0.02217317870199898, 0.022327914942275515, 0.013476477468829826]
# [[ 147.07784855    0.41290415  142.30786058]
#  [ 252.03328614  252.52328345  252.46992414]
#  [  48.40014194   18.68572949   38.82979478]
#  [ 211.46746083  163.30526378  123.44856523]
#  [  72.09378652  136.20403194  203.75691469]]
